# %%
#variables are dynamically typed
n = 0
print(n)
print(type(n))
n = 'zero'
print(n)
print(type(n))
# Out:
# 0
# <class 'int'>
# zero
# <class 'str'>

# %%
#multiple assignments
a,b = 10,20
print(a)
print(b)
